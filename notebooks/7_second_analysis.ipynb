# %%
import os
import time
import json
from pathlib import Path
import pandas as pd
import glob
import numpy as np
import pprint
import requests
from datetime import datetime

# %%
df_thursdays = pd.read_csv("thursday_vote_outcomes_council_win_or_lose.csv")
df_thursdays.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                                        vote_id  \
# 0             0           0  eli/dl/event/MTG-PL-2025-10-23-VOT-ITM-975331
# 1            19          19  eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
# 2            29          29  eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
# 3            24          24  eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
# 4            33          33  eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
#
#                                  decision_id                 start_date  \
# 0  eli/dl/event/MTG-PL-2025-10-23-DEC-180520  2025-10-23T13:08:06+02:00
# 1  eli/dl/event/MTG-PL-2026-07-09-DEC-195775  2026-07-09T13:21:39+02:00
# 2  eli/dl/event/MTG-PL-2026-07-09-DEC-195776  2026-07-09T13:22:14+02:00
# 3  eli/dl/event/MTG-PL-2026-07-09-DEC-195777  2026-07-09T13:22:31+02:00
# 4  eli/dl/event/MTG-PL-2026-07-09-DEC-195778  2026-07-09T13:22:50+02:00
#
#                                              method                   outcome  \
# 0  def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL  def/ep-statuses/REJECTED
# 1  def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL  def/ep-statuses/REJECTED
# 2  def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL  def/ep-statuses/REJECTED
# 3  def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL  def/ep-statuses/REJECTED
# 4  def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL   def/ep-statuses/ADOPTED
#
#    attendees  votes_favor  votes_against  \
# 0      571.0        220.0          341.0
# 1      607.0        314.0          276.0
# 2      605.0        117.0          422.0
# 3      596.0        114.0          422.0
# 4      611.0        369.0          236.0
#
#                                    heading master_doc  item_number  \
# 0  Proposal to reject the Council position        NaN          NaN
# 1  Proposal to reject the Council position        NaN          NaN
# 2                   Draft legislative act         NaN          NaN
# 3                   Draft legislative act         NaN          NaN
# 4                   Draft legislative act         NaN          NaN
#
#    abstentions Council win or loss
# 0          NaN         Council win
# 1          NaN         Council win
# 2          NaN         Council win
# 3          NaN         Council win
# 4          NaN        Council loss

# %%
#Doing a sanity check on votes that achieved absolute majority
df_thursdays[df_thursdays["votes_favor"] > 361]
# Out:
#     Unnamed: 0.1  Unnamed: 0                                        vote_id  \
# 4             33          33  eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
# 13            31          31  eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
#
#                                   decision_id                 start_date  \
# 4   eli/dl/event/MTG-PL-2026-07-09-DEC-195778  2026-07-09T13:22:50+02:00
# 13  eli/dl/event/MTG-PL-2026-07-09-DEC-195787  2026-07-09T13:25:49+02:00
#
#                                               method                  outcome  \
# 4   def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL  def/ep-statuses/ADOPTED
# 13  def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL  def/ep-statuses/ADOPTED
#
#     attendees  votes_favor  votes_against                 heading master_doc  \
# 4       611.0        369.0          236.0  Draft legislative act         NaN
# 13      602.0        362.0          235.0  Draft legislative act         NaN
#
#     item_number  abstentions Council win or loss
# 4           NaN          NaN        Council loss
# 13          NaN          NaN        Council loss

# %%
#Sanity check for votes that achieved simple majority only
mask = (361 > df_thursdays['votes_favor']) & (df_thursdays['votes_favor'] > df_thursdays['votes_against'])
df_simple_maj = df_thursdays[mask].copy()

df_simple_maj
# Out:
#     Unnamed: 0.1  Unnamed: 0                                        vote_id  \
# 1             19          19  eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
# 9             14          14  eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
# 12            21          21  eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
# 14            30          30  eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
# 22            35          35  eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
#
#                                   decision_id                 start_date  \
# 1   eli/dl/event/MTG-PL-2026-07-09-DEC-195775  2026-07-09T13:21:39+02:00
# 9   eli/dl/event/MTG-PL-2026-07-09-DEC-195783  2026-07-09T13:24:23+02:00
# 12  eli/dl/event/MTG-PL-2026-07-09-DEC-195786  2026-07-09T13:25:26+02:00
# 14  eli/dl/event/MTG-PL-2026-07-09-DEC-195788  2026-07-09T13:26:11+02:00
# 22  eli/dl/event/MTG-PL-2026-07-09-DEC-195796  2026-07-09T13:28:06+02:00
#
#                                               method  \
# 1   def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL
# 9   def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL
# 12  def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL
# 14  def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL
# 22  def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL
#
#                      outcome  attendees  votes_favor  votes_against  \
# 1   def/ep-statuses/REJECTED      607.0        314.0          276.0
# 9   def/ep-statuses/REJECTED      600.0        345.0          237.0
# 12  def/ep-statuses/REJECTED      603.0        346.0          254.0
# 14  def/ep-statuses/REJECTED      613.0        322.0          255.0
# 22  def/ep-statuses/REJECTED      614.0        353.0          254.0
#
#                                     heading master_doc  item_number  \
# 1   Proposal to reject the Council position        NaN          NaN
# 9                    Draft legislative act         NaN          NaN
# 12                   Draft legislative act         NaN          NaN
# 14                   Draft legislative act         NaN          NaN
# 22                   Draft legislative act         NaN          NaN
#
#     abstentions Council win or loss
# 1           NaN         Council win
# 9           NaN         Council win
# 12          NaN         Council win
# 14          NaN         Council win
# 22          NaN         Council win

# %%
df_weekdays = pd.read_csv("weekday_vote_results_council_wins_losses.csv")
df_weekdays.head()
# Out:
#    Unnamed: 0                                        vote_id  \
# 0           0  eli/dl/event/MTG-PL-2024-10-22-VOT-ITM-962879
# 1           1  eli/dl/event/MTG-PL-2024-12-17-VOT-ITM-965069
# 2           2  eli/dl/event/MTG-PL-2025-05-06-VOT-ITM-965509
# 3           3  eli/dl/event/MTG-PL-2025-05-06-VOT-ITM-965500
# 4           4  eli/dl/event/MTG-PL-2025-05-06-VOT-ITM-965505
#
#                                  decision_id master_doc  item_number  \
# 0  eli/dl/event/MTG-PL-2024-10-22-DEC-170219        NaN          NaN
# 1  eli/dl/event/MTG-PL-2024-12-17-DEC-171264        NaN          NaN
# 2  eli/dl/event/MTG-PL-2025-05-06-DEC-176083        NaN          NaN
# 3  eli/dl/event/MTG-PL-2025-05-06-DEC-176082        NaN          NaN
# 4  eli/dl/event/MTG-PL-2025-05-06-DEC-176084        NaN          NaN
#
#    start_date        method   outcome  attendees  votes_favor  votes_against  \
# 0         NaN  Auto-adopted  Approved        NaN          NaN            NaN
# 1         NaN  Auto-adopted  Approved        NaN          NaN            NaN
# 2         NaN  Auto-adopted  Approved        NaN          NaN            NaN
# 3         NaN  Auto-adopted  Approved        NaN          NaN            NaN
# 4         NaN  Auto-adopted  Approved        NaN          NaN            NaN
#
#    abstentions heading Council win or loss
# 0          NaN     NaN         Council win
# 1          NaN     NaN         Council win
# 2          NaN     NaN         Council win
# 3          NaN     NaN         Council win
# 4          NaN     NaN         Council win

# %%
print(df_thursdays["Council win or loss"].value_counts(normalize=True, dropna=False) * 100)
print(df_weekdays["Council win or loss"].value_counts(normalize=True, dropna=False) * 100)
# Out:
# Council win or loss
# Council win     93.333333
# Council loss     4.444444
# Unknown          2.222222
# Name: proportion, dtype: float64
# Council win or loss
# Council win     92.452830
# Council loss     5.660377
# Unknown          1.886792
# Name: proportion, dtype: float64

# %%
#Let's check what the "Unknown" outcomes actually were manually
df_thursdays[df_thursdays["Council win or loss"] == "Unknown"]
#Double checking this one shows that the vot itm 64 is missing from the official
#document recording the votes taken on that meeting
# Out:
#     Unnamed: 0.1  Unnamed: 0  \
# 37            37          37
#
#                                              vote_id decision_id start_date  \
# 37  eli/dl/event/MTG-PL-2014-04-03-VOT-ITM-350882-64         NaN        NaN
#
#      method  outcome  attendees  votes_favor  votes_against heading  \
# 37  Unknown  Unknown        NaN          NaN            NaN     NaN
#
#                         master_doc  item_number  abstentions  \
# 37  eli/dl/doc/PV-7-2014-04-03-VOT         64.0          NaN
#
#    Council win or loss
# 37             Unknown

# %%
df_weekdays[df_weekdays["Council win or loss"] == "Unknown"]
#double checking this one shows also that there is no record of an outcome
# Out:
#     Unnamed: 0                                          vote_id decision_id  \
# 28          29  eli/dl/event/MTG-PL-2015-03-10-VOT-ITM-409208-6         NaN
#
#                         master_doc  item_number  start_date   method  outcome  \
# 28  eli/dl/doc/PV-8-2015-03-10-VOT          6.0         NaN  Unknown  Unknown
#
#     attendees  votes_favor  votes_against  abstentions heading  \
# 28        NaN          NaN            NaN          NaN     NaN
#
#    Council win or loss
# 28             Unknown

# %%
#To complete our dataframes we remove the rows with "Unknown" in "Counsil_win_or_loss"
df_thursdays = df_thursdays[df_thursdays["Council win or loss"] != "Unknown"]

# %%
df_thursdays = df_thursdays[df_thursdays["Council win or loss"] != "Unknown"]

# %%
df_weekdays = df_weekdays[df_weekdays["Council win or loss"] != "Unknown"]

# %%
print(df_thursdays["Council win or loss"].value_counts(normalize=True, dropna=False) * 100)
print(df_weekdays["Council win or loss"].value_counts(normalize=True, dropna=False) * 100)
# Out:
# Council win or loss
# Council win     95.454545
# Council loss     4.545455
# Name: proportion, dtype: float64
# Council win or loss
# Council win     94.230769
# Council loss     5.769231
# Name: proportion, dtype: float64

# %%
df_thursdays.to_csv("thursday_votes_cleaned.csv")
df_weekdays.to_csv("weekday_votes_cleaned.csv")

# %%
df_thursdays["day_category"] = "Thursday"
df_weekdays["day_category"] = "Weekday"

# %%
#and one combined
df_combined = pd.concat([df_thursdays, df_weekdays], ignore_index=True)

# %%
df_combined = df_combined.drop(columns=["Unnamed: 0.1", "Unnamed: 0"])

# %%
df_combined.head()
# Out:
#                                          vote_id  \
# 0  eli/dl/event/MTG-PL-2025-10-23-VOT-ITM-975331
# 1  eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
# 2  eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
# 3  eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
# 4  eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
#
#                                  decision_id                 start_date  \
# 0  eli/dl/event/MTG-PL-2025-10-23-DEC-180520  2025-10-23T13:08:06+02:00
# 1  eli/dl/event/MTG-PL-2026-07-09-DEC-195775  2026-07-09T13:21:39+02:00
# 2  eli/dl/event/MTG-PL-2026-07-09-DEC-195776  2026-07-09T13:22:14+02:00
# 3  eli/dl/event/MTG-PL-2026-07-09-DEC-195777  2026-07-09T13:22:31+02:00
# 4  eli/dl/event/MTG-PL-2026-07-09-DEC-195778  2026-07-09T13:22:50+02:00
#
#                                              method                   outcome  \
# 0  def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL  def/ep-statuses/REJECTED
# 1  def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL  def/ep-statuses/REJECTED
# 2  def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL  def/ep-statuses/REJECTED
# 3  def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL  def/ep-statuses/REJECTED
# 4  def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL   def/ep-statuses/ADOPTED
#
#    attendees  votes_favor  votes_against  \
# 0      571.0        220.0          341.0
# 1      607.0        314.0          276.0
# 2      605.0        117.0          422.0
# 3      596.0        114.0          422.0
# 4      611.0        369.0          236.0
#
#                                    heading master_doc  item_number  \
# 0  Proposal to reject the Council position        NaN          NaN
# 1  Proposal to reject the Council position        NaN          NaN
# 2                   Draft legislative act         NaN          NaN
# 3                   Draft legislative act         NaN          NaN
# 4                   Draft legislative act         NaN          NaN
#
#    abstentions Council win or loss day_category
# 0          NaN         Council win     Thursday
# 1          NaN         Council win     Thursday
# 2          NaN         Council win     Thursday
# 3          NaN         Council win     Thursday
# 4          NaN        Council loss     Thursday

# %%
df_combined.to_csv("combined_votes_cleaned.csv")

# %%
df_combined = pd.read_csv("combined_votes_cleaned.csv")

# %%
df_combined["day_category"].value_counts()
# Out:
# day_category
# Weekday     52
# Thursday    44
# Name: count, dtype: int64

# %%
clean_dates = df_combined["vote_id"].str.replace("eli/dl/event/MTG-PL-", "").str[:10]

date_objs = pd.to_datetime(clean_dates, errors="coerce")
days = date_objs.dt.day_name()

not_thursdays = df_combined["day_category"] == "Weekday"
df_combined.loc[not_thursdays, "day_category"] = days[not_thursdays]

print(df_combined["day_category"].value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of 0      Thursday
# 1      Thursday
# 2      Thursday
# 3      Thursday
# 4      Thursday
#         ...
# 91    Wednesday
# 92    Wednesday
# 93      Tuesday
# 94      Tuesday
# 95    Wednesday
# Name: day_category, Length: 96, dtype: str>

# %%
df_combined["day_category"].value_counts()
# Out:
# day_category
# Thursday     44
# Tuesday      32
# Wednesday    20
# Name: count, dtype: int64

# %%
df_combined.to_csv("combined_votes_cleaned.csv")

# %%
df_combined.head(60)
# Out:
#     Unnamed: 0                                          vote_id  \
# 0            0    eli/dl/event/MTG-PL-2025-10-23-VOT-ITM-975331
# 1            1    eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
# 2            2    eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
# 3            3    eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
# 4            4    eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
# 5            5    eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
# 6            6    eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
# 7            7    eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
# 8            8    eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
# 9            9    eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
# 10          10    eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
# 11          11    eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
# 12          12    eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
# 13          13    eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
# 14          14    eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
# 15          15    eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
# 16          16    eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
# 17          17    eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
# 18          18    eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
# 19          19    eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
# 20          20    eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
# 21          21    eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
# 22          22    eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
# 23          23    eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
# 24          24    eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
# 25          25    eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
# 26          26    eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
# 27          27    eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
# 28          28    eli/dl/event/MTG-PL-2026-07-09-VOT-ITM-993015
# 29          29    eli/dl/event/MTG-PL-2025-10-23-VOT-ITM-975337
# 30          30    eli/dl/event/MTG-PL-2025-11-13-VOT-ITM-975467
# 31          31    eli/dl/event/MTG-PL-2025-11-13-VOT-ITM-975415
# 32          32    eli/dl/event/MTG-PL-2026-01-22-VOT-ITM-982162
# 33          33    eli/dl/event/MTG-PL-2026-03-26-VOT-ITM-987077
# 34          34    eli/dl/event/MTG-PL-2026-03-26-VOT-ITM-987073
# 35          35    eli/dl/event/MTG-PL-2026-03-26-VOT-ITM-987078
# 36          36    eli/dl/event/MTG-PL-2026-03-26-VOT-ITM-987079
# 37          37  eli/dl/event/MTG-PL-2014-04-03-VOT-ITM-350903-1
# 38          38  eli/dl/event/MTG-PL-2016-04-14-VOT-ITM-522221-1
# 39          39  eli/dl/event/MTG-PL-2016-04-14-VOT-ITM-522222-2
# 40          40  eli/dl/event/MTG-PL-2016-04-28-VOT-ITM-520210-7
# 41          41  eli/dl/event/MTG-PL-2016-04-28-VOT-ITM-520211-8
# 42          42  eli/dl/event/MTG-PL-2016-04-28-VOT-ITM-520212-9
def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL
# 1   def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL
# 2   def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL
# 3   def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL
# 4   def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL
# 5   def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL
# 6   def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL
# 7   def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL
# 8   def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL
# 9   def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL
# 10  def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL
# 11  def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL
# 12  def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL
# 13  def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL
# 14  def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL
# 15  def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL
# 16  def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL
# 17  def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL
# 18  def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL
# 19  def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL
# 20  def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL
# 21  def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL
# 22  def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL
# 23  def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL
# 24  def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL
# 25  def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL
# 26  def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL
# 27  def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL
# 28  def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL
# 29                                      Auto-adopted
# 30                                      Auto-adopted
# 31                                      Auto-adopted
# 32                                      Auto-adopted
# 33                                      Auto-adopted
# 34                                      Auto-adopted
# 35                                      Auto-adopted
# 36                                      Auto-adopted
# 37                                      Auto-adopted
# 38                                      Auto-adopted
# 39                                      Auto-adopted
# 40                                      Auto-adopted
# 41                                      Auto-adopted
# 42                            Roll Call / Electronic
# 43                            Roll Call / Electronic
# 44                                      Auto-adopted
# 45                                      Auto-adopted
# 46                                      Auto-adopted
# 47                                      Auto-adopted
# 48                                      Auto-adopted
# 49                                      Auto-adopted
# 50                 def/ep-decision-methods/VOTE_HAND
# 51                                      Auto-adopted
# 52                                      Auto-adopted
# 53                                      Auto-adopted
# 54  def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL
# 55  def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL
# 56  def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL
# 57                 def/ep-decision-methods/VOTE_HAND
# 58                 def/ep-decision-methods/VOTE_HAND
# 59  def/ep-decision-methods/VOTE_ELECTRONIC_ROLLCALL
#
#                      outcome  attendees  votes_favor  votes_against  \
# 0   def/ep-statuses/REJECTED      571.0        220.0          341.0
# 1   def/ep-statuses/REJECTED      607.0        314.0          276.0
# 2   def/ep-statuses/REJECTED      605.0        117.0          422.0
# 3   def/ep-statuses/REJECTED      596.0        114.0          422.0
# 4    def/ep-statuses/ADOPTED      611.0        369.0          236.0
# 5   def/ep-statuses/REJECTED      606.0        161.0          433.0
# 6   def/ep-statuses/REJECTED      605.0        120.0          433.0
# 7   def/ep-statuses/REJECTED      602.0        158.0          433.0
# 8   def/ep-statuses/REJECTED      604.0        119.0          434.0
# 9   def/ep-statuses/REJECTED      600.0        345.0          237.0
# 10  def/ep-statuses/REJECTED      604.0        160.0          433.0
# 11  def/ep-statuses/REJECTED      601.0        161.0          430.0
# 12  def/ep-statuses/REJECTED      603.0        346.0          254.0
# 13   def/ep-statuses/ADOPTED      602.0        362.0          235.0
# 14  def/ep-statuses/REJECTED      613.0        322.0          255.0
# 15  def/ep-statuses/REJECTED      605.0        175.0          408.0
# 16  def/ep-statuses/REJECTED      594.0        154.0          421.0
# 17  def/ep-statuses/REJECTED      606.0         86.0          479.0
# 18  def/ep-statuses/REJECTED      606.0        119.0          436.0
# 19  def/ep-statuses/REJECTED      604.0        110.0          432.0
# 20  def/ep-statuses/REJECTED      606.0        142.0          434.0
# 21  def/ep-statuses/REJECTED      597.0        175.0          399.0
# 22  def/ep-statuses/REJECTED      614.0        353.0          254.0
# 23  def/ep-statuses/REJECTED      603.0        164.0          425.0
# 24  def/ep-statuses/REJECTED      601.0        170.0          412.0
# 25  def/ep-statuses/REJECTED      608.0        257.0          292.0
# 26  def/ep-statuses/REJECTED      604.0        162.0          424.0
# 27  def/ep-statuses/REJECTED      562.0        157.0          385.0
# 28  def/ep-statuses/REJECTED      592.0        276.0          286.0
# 29     Approval without vote        NaN          NaN            NaN
# 30     Approval without vote        NaN          NaN            NaN
# 31     Approval without vote        NaN          NaN            NaN
# 32     Approval without vote        NaN          NaN            NaN
# 33     Approval without vote        NaN          NaN            NaN
# 34     Approval without vote        NaN          NaN            NaN
# 35     Approval without vote        NaN          NaN            NaN
# 36     Approval without vote        NaN          NaN            NaN
# 37                  Approved        NaN          NaN            NaN
# 38                  Approved        NaN          NaN            NaN
# 39                  Approved        NaN          NaN            NaN
# 40                  Approved        NaN          NaN            NaN
# 41                  Approved        NaN          NaN            NaN
# 42                  Approved        NaN         88.0          534.0
# 43                  Approved        NaN         48.0          565.0
# 44                  Approved        NaN          NaN            NaN
# 45                  Approved        NaN          NaN            NaN
# 46                  Approved        NaN          NaN            NaN
# 47                  Approved        NaN          NaN            NaN
# 48                  Approved        NaN          NaN            NaN
# 49                  Approved        NaN          NaN            NaN
# 50  def/ep-statuses/REJECTED        NaN          NaN            NaN
# 51                  Approved        NaN          NaN            NaN
# 52                  Approved        NaN          NaN            NaN
# 53                  Approved        NaN          NaN            NaN
# 54  def/ep-statuses/REJECTED      661.0        122.0          470.0
# 55  def/ep-statuses/REJECTED      660.0        132.0          467.0
# 56   def/ep-statuses/ADOPTED      656.0        632.0           15.0
# 57  def/ep-statuses/REJECTED        NaN          NaN            NaN
# 58  def/ep-statuses/REJECTED        NaN          NaN            NaN
# 59  def/ep-statuses/REJECTED      657.0        270.0          349.0
#
#                                     heading                      master_doc  \
# 0   Proposal to reject the Council position                             NaN
# 1   Proposal to reject the Council position                             NaN
# 2                    Draft legislative act                              NaN
# 3                    Draft legislative act                              NaN
# 4                    Draft legislative act                              NaN
# 5                    Draft legislative act                              NaN
# 6                    Draft legislative act                              NaN
# 7                    Draft legislative act                              NaN
# 8                    Draft legislative act                              NaN
# 9                    Draft legislative act                              NaN
# 10                   Draft legislative act                              NaN
# 11                   Draft legislative act                              NaN
# 12                   Draft legislative act                              NaN
# 13                   Draft legislative act                              NaN
# 14                   Draft legislative act                              NaN
# 15                   Draft legislative act                              NaN
# 16                   Draft legislative act                              NaN
# 17                   Draft legislative act                              NaN
# 18                   Draft legislative act                              NaN
# 19                   Draft legislative act                              NaN
# 20                   Draft legislative act                              NaN
# 21                   Draft legislative act                              NaN
# 22                   Draft legislative act                              NaN
# 23                   Draft legislative act                              NaN
# 24                   Draft legislative act                              NaN
# 25                   Draft legislative act                              NaN
# 26                   Draft legislative act                              NaN
# 27                   Draft legislative act                              NaN
# 28      Proposal for rejection (Rule 68(4))                             NaN
# 29                                      NaN                             NaN
# 30                                      NaN                             NaN
# 31                                      NaN                             NaN
# 32                                      NaN                             NaN
# 33                                      NaN                             NaN
# 34                                      NaN                             NaN
# 35                                      NaN                             NaN
# 36                                      NaN                             NaN
# 37                                      NaN  eli/dl/doc/PV-7-2014-04-03-VOT
# 38                                      NaN  eli/dl/doc/PV-8-2016-04-14-VOT
# 39                                      NaN  eli/dl/doc/PV-8-2016-04-14-VOT
# 40                                      NaN  eli/dl/doc/PV-8-2016-04-28-VOT
# 41                                      NaN  eli/dl/doc/PV-8-2016-04-28-VOT
# 42                                      NaN  eli/dl/doc/PV-8-2016-04-28-VOT
# 43                                      NaN  eli/dl/doc/PV-8-2016-06-09-VOT
# 44                                      NaN                             NaN
# 45                                      NaN                             NaN
# 46                                      NaN                             NaN
# 47                                      NaN                             NaN
# 48                                      NaN                             NaN
# 49                                      NaN                             NaN
# 50                                      NaN                             NaN
# 51                                      NaN                             NaN
# 52                                      NaN                             NaN
# 53                                      NaN                             NaN
# 54                                      NaN                             NaN
# 55                                      NaN                             NaN
# 56                                      NaN                             NaN
# 57                                      NaN                             NaN
# 58                    Draft legislative act                             NaN
# 59                                      NaN                             NaN
#
#     item_number  abstentions Council win or loss day_category
# 0           NaN          NaN         Council win     Thursday
# 1           NaN          NaN         Council win     Thursday
# 2           NaN          NaN         Council win     Thursday
# 3           NaN          NaN         Council win     Thursday
# 4           NaN          NaN        Council loss     Thursday
# 5           NaN          NaN         Council win     Thursday
# 6           NaN          NaN         Council win     Thursday
# 7           NaN          NaN         Council win     Thursday
# 8           NaN          NaN         Council win     Thursday
# 9           NaN          NaN         Council win     Thursday
# 10          NaN          NaN         Council win     Thursday
# 11          NaN          NaN         Council win     Thursday
# 12          NaN          NaN         Council win     Thursday
# 13          NaN          NaN        Council loss     Thursday
# 14          NaN          NaN         Council win     Thursday
# 15          NaN          NaN         Council win     Thursday
# 16          NaN          NaN         Council win     Thursday
# 17          NaN          NaN         Council win     Thursday
# 18          NaN          NaN         Council win     Thursday
# 19          NaN          NaN         Council win     Thursday
# 20          NaN          NaN         Council win     Thursday
# 21          NaN          NaN         Council win     Thursday
# 22          NaN          NaN         Council win     Thursday
# 23          NaN          NaN         Council win     Thursday
# 24          NaN          NaN         Council win     Thursday
# 25          NaN          NaN         Council win     Thursday
# 26          NaN          NaN         Council win     Thursday
# 27          NaN          NaN         Council win     Thursday
# 28          NaN          NaN         Council win     Thursday
# 29          NaN          NaN         Council win     Thursday
# 30          NaN          NaN         Council win     Thursday
# 31          NaN          NaN         Council win     Thursday
# 32          NaN          NaN         Council win     Thursday
# 33          NaN          NaN         Council win     Thursday
# 34          NaN          NaN         Council win     Thursday
# 35          NaN          NaN         Council win     Thursday
# 36          NaN          NaN         Council win     Thursday
# 37          1.0          NaN         Council win     Thursday
# 38          1.0          NaN         Council win     Thursday
# 39          2.0          NaN         Council win     Thursday
# 40          7.0          NaN         Council win     Thursday
# 41          8.0          NaN         Council win     Thursday
# 42          9.0         11.0         Council win     Thursday
# 43          4.0          4.0         Council win     Thursday
# 44          NaN          NaN         Council win      Tuesday
# 45          NaN          NaN         Council win      Tuesday
# 46          NaN          NaN         Council win      Tuesday
# 47          NaN          NaN         Council win      Tuesday
# 48          NaN          NaN         Council win      Tuesday
# 49          NaN          NaN         Council win      Tuesday
# 50          NaN          NaN         Council win      Tuesday
# 51          NaN          NaN         Council win      Tuesday
# 52          NaN          NaN         Council win      Tuesday
# 53          NaN          NaN         Council win      Tuesday
# 54          NaN          NaN         Council win      Tuesday
# 55          NaN          NaN         Council win      Tuesday
# 56          NaN          NaN        Council loss    Wednesday
# 57          NaN          NaN         Council win      Tuesday
# 58          NaN          NaN         Council win      Tuesday
# 59          NaN          NaN         Council win    Wednesday

# %%
df_combined[]
